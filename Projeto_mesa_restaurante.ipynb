# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorDiasDev/Projetos_Analise_de_Dados/blob/main/Projeto_mesa_restaurante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# Definir tema
sns.set_theme(style='darkgrid')

# %%
# Dados
base_dados = sns.load_dataset('tips')

# Verificar
base_dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Renomeando as colunas
base_dados.rename(columns= {
    'total_bill': 'Total Conta',
    'tip': 'Gorjeta',
    'sex': 'Sexo',
    'smoker': 'Fumante',
    'day': 'Dia Semana',
    'time': 'Periodo',
    'size': 'Pessoas na Mesa'
}, inplace=True )

# %%
base_dados.head()
# Out:
#    Total Conta  Gorjeta    Sexo Fumante Dia Semana Periodo  Pessoas na Mesa
# 0        16.99     1.01  Female      No        Sun  Dinner                2
# 1        10.34     1.66    Male      No        Sun  Dinner                3
# 2        21.01     3.50    Male      No        Sun  Dinner                3
# 3        23.68     3.31    Male      No        Sun  Dinner                2
# 4        24.59     3.61  Female      No        Sun  Dinner                4

# %%
# Gráfico relplot
sns.relplot(x='Total Conta', y='Gorjeta', data = base_dados)

# %%
# Gráfico relplot
# Passando outro parâmetro como classe no gráfico
sns.relplot(x='Total Conta', y='Gorjeta', data=base_dados, hue='Sexo');

# %%
# Gráfico de linha com 2 eixos
sns.relplot(x='Total Conta', y='Gorjeta', data=base_dados, hue='Sexo', kind='line');

# %%
# Gráfico de linha com 2 eixos
sns.relplot(x='Total Conta', y='Gorjeta', data=base_dados, hue='Fumante', kind='line');

# %%
# Gráfico histplot
sns.histplot(data=base_dados, x='Total Conta');

# %%
# Gráfico histplot
sns.histplot(data=base_dados, x='Total Conta', hue='Fumante');

# %%
# Gráfico barplot
sns.barplot(data=base_dados, x='Sexo', y='Total Conta', hue='Fumante');

# %%
# Gráfico pairplot
sns.pairplot(base_dados)

# %%
sns.pairplot(base_dados, hue='Sexo');

# %%
sns.pairplot(base_dados, kind='kde');

# %%
sns.boxplot(data=base_dados, x='Dia Semana', y='Total Conta')

# %%
sns.boxplot(data=base_dados, x='Dia Semana', y='Total Conta', hue='Sexo');
